# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
y_reverse = y[::-1]

plt.figure(figsize=(20, 5))
plt.title("asdf")
plt.plot(y,'r', marker='.',linestyle='dotted', label ='asc')
plt.plot(y_reverse, marker='.',label ='desc')
plt.legend()
plt.show()

# %%
ls
# Out:
# 0914_1(csv 데이터 불러오기).ipynb
# 0914_2(서울의 최고기온).ipynb
# 0921_1(서울의 최저, 최고 기온).ipynb
# 0921_2(내 생월의 최고,최저 기온).ipynb
# 0921_3(서울 전체 기온 그래프).ipynb
# 0921_4(서울의 최고기온 숏코딩).ipynb
# README.md
# data_analysis.ipynb
# plot_example.ipynb
# seoul.csv
# seoul_data.csv
