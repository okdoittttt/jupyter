# %%
import csv

# windows os = 'cp949', mac os = 'utf-8'
f = open('seoul.csv', 'r', encoding='utf-8')

data = csv.reader(f, delimiter=',')

print(data)

# %%
###### Head 처리 ######
head = next(data)
print(head)
# Out:
# ['date', 'loca', 'avg', 'max', 'min']

# %%
for raw in data:
#    print(raw)
#    print(len(raw))
# Out:
# ['1907-10', '108', '13.9', '25.4', '8.3']
# ['1907-11', '108', '5.3', '21.3', '0.6']
# ['1907-12', '108', '-3.9', '9', '-8.7']
# ['1908-01', '108', '-3.5', '6.2', '-7.5']
# ['1908-02', '108', '-4', '8.4', '-8.8']
# ['1908-03', '108', '2.9', '18.2', '-1.7']
# ['1908-04', '108', '10.1', '22.9', '4.6']
# ['1908-05', '108', '14.9', '25.2', '10']
# ['1908-06', '108', '20.7', '32.4', '16.3']
# ['1908-07', '108', '23.5', '32.9', '20.3']
# ['1908-08', '108', '24.3', '33.6', '21']
# ['1908-09', '108', '19.3', '28.7', '14.7']
# ['1908-10', '108', '13.6', '25.3', '7.7']
# ['1908-11', '108', '3.6', '18.9', '-1.5']
# ['1908-12', '108', '-0.8', '11.7', '-6']
# ['1909-01', '108', '-2.5', '7.6', '-7.3']
# ['1909-02', '108', '-3.2', '8.8', '-8.6']
# ['1909-03', '108', '1.8', '15.2', '-3.1']
# ['1909-04', '108', '10.4', '23.3', '4.6']
# ['1909-05', '108', '15.4', '29.8', '10.2']
# ['1909-06', '108', '20.6', '31.7', '15.8']
# ['1909-07', '108', '24.6', '31.8', '21.4']
# ...

# %%
f.close()
